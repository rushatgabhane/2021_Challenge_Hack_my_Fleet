# %%
import pandas as pd
import numpy as np
import os

# %%
df1 = pd.read_csv('data/hack_illinois_part1.csv')

# %%
df2 = pd.read_csv('data/hack_illinois_part2.csv')

# %%
df3 = pd.concat([df,df2]).drop("Unnamed: 0",axis=1)

# %%
df3

# %%
df3.to_csv('data/hack_illinois.csv', index=False)

# %%
pd.read_csv('data/hack_illinois.csv')
# Out:
#           AssetID        Date          Asset type  Total Hours  \
# 0         1022011  2018-04-06        Motor Grader         4.03
# 1         1022011  2018-04-07        Motor Grader         7.34
# 2         1022011  2018-04-08        Motor Grader         7.27
# 3         1022011  2018-04-09        Motor Grader         7.35
# 4         1022011  2018-04-10        Motor Grader        13.39
# ...           ...         ...                 ...          ...
# 14599995  1042010  2019-04-01  Track Type Tractor        21.93
# 14599996  1042010  2019-04-02  Track Type Tractor        23.91
# 14599997  1042010  2019-04-03  Track Type Tractor         1.20
# 14599998  1042010  2019-04-04  Track Type Tractor         7.76
# 14599999  1042010  2019-04-05  Track Type Tractor        12.07
#
#           Total Fuel (Liters)  Fuel Level (%)  GPS Lattitude  GPS Longitude
# 0                      333.13           97.79      37.501627     -79.868284
# ...
